# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.lines as mlines

import nltk
from nltk.tokenize import ToktokTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from string import punctuation

import re
from bs4 import BeautifulSoup

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.linear_model import SGDClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import hamming_loss
from sklearn.metrics import confusion_matrix

from scipy.sparse import hstack

# %%
questions = pd.read_csv("Questions.csv")
questions.head()
# Out:
#     Id  OwnerUserId          CreationDate  Score  \
# 0  469        147.0  2008-08-02T15:11:16Z     21
# 1  502        147.0  2008-08-02T17:01:58Z     27
# 2  535        154.0  2008-08-02T18:43:54Z     40
# 3  594        116.0  2008-08-03T01:15:08Z     25
# 4  683        199.0  2008-08-03T13:19:16Z     28
#
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607282 entries, 0 to 607281
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Id            607282 non-null  int64
#  1   OwnerUserId   601070 non-null  float64
#  2   CreationDate  607282 non-null  object
#  3   Score         607282 non-null  int64
#  4   Title         607282 non-null  object
#  5   Body          607282 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 27.8+ MB

# %%
tags = pd.read_csv("Tags.csv", dtype={'Tag':str})
tags.head()
# Out:
#     Id        Tag
# 0  469     python
# 1  469        osx
# 2  469      fonts
# 3  469  photoshop
# 4  502     python

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1885078 entries, 0 to 1885077
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Tag     object
# dtypes: int64(1), object(1)
# memory usage: 28.8+ MB

# %%
tags['Tag'] = tags['Tag'].astype(str)

# %%
grouped_tags = tags.groupby("Id")['Tag'].apply(lambda tags: ' '.join(tags))

# %%
grouped_tags.head()
# Out:
# Id
# 469                           python osx fonts photoshop
# 502                             python windows image pdf
# 535    python continuous-integration extreme-programming
# 594                 python sql database oracle cx-oracle
# 683                              python arrays iteration
# Name: Tag, dtype: object

# %%
grouped_tags.reset_index()
# Out:
#               Id                                                Tag
# 0            469                         python osx fonts photoshop
# 1            502                           python windows image pdf
# 2            535  python continuous-integration extreme-programming
# 3            594               python sql database oracle cx-oracle
# 4            683                            python arrays iteration
# ...          ...                                                ...
# 607278  40143190                              python bash multiline
# 607279  40143228                          python selenium-webdriver
# 607280  40143267                python django django-rest-framework
# 607281  40143338                                             python
# 607282  40143365                           python numpy theano nnet
#
# [607283 rows x 2 columns]

# %%
grouped_tags_final = pd.DataFrame({'Id':grouped_tags.index, 'Tags':grouped_tags.values})

# %%
grouped_tags_final.head(5)
# Out:
#     Id                                               Tags
# 0  469                         python osx fonts photoshop
# 1  502                           python windows image pdf
# 2  535  python continuous-integration extreme-programming
# 3  594               python sql database oracle cx-oracle
# 4  683                            python arrays iteration

# %%
questions.drop(columns=['OwnerUserId', 'CreationDate'], inplace=True)

# %%
questions = questions.merge(grouped_tags_final, on='Id')
questions.head()
# Out:
#     Id  Score                                              Title  \
# 0  469     21  How can I find the full path to a font from it...
# 1  502     27            Get a preview JPEG of a PDF on Windows?
# 2  535     40  Continuous Integration System for a Python Cod...
# 3  594     25     cx_Oracle: How do I iterate over a result set?
# 4  683     28  Using 'in' to match an attribute of Python obj...
#
#                                                 Body  \
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...
#
#                                                 Tags
# 0                         python osx fonts photoshop
# 1                           python windows image pdf
# 2  python continuous-integration extreme-programming
# 3               python sql database oracle cx-oracle
# 4                            python arrays iteration

# %%
filtered_questions = questions[questions['Score']>5]

# %%
filtered_questions.drop(columns = ['Id', 'Score'], inplace=True)
# Out:
# d:\python\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
filtered_questions.head()
# Out:
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body  \
# 0  <p>I am using the Photoshop's javascript API t...
# 1  <p>I have a cross-platform (Python) applicatio...
# 2  <p>I'm starting work on a hobby project with a...
# 3  <p>There are several ways to iterate over a re...
# 4  <p>I don't remember whether I was dreaming or ...
#
#                                                 Tags
# 0                         python osx fonts photoshop
# 1                           python windows image pdf
# 2  python continuous-integration extreme-programming
# 3               python sql database oracle cx-oracle
# 4                            python arrays iteration

# %%
filtered_questions['Tags'] = filtered_questions['Tags'].apply(lambda x: x.split())

all_tags = [item for sublist in filtered_questions['Tags'].values for item in sublist]

print(len(all_tags))

my_set = set(all_tags)
unique_tags = list(my_set)
print(len(unique_tags))
# Out:
# 134101
# 6384
# <ipython-input-17-c3e4bca95c73>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Tags'] = filtered_questions['Tags'].apply(lambda x: x.split())

# %%
flat_list = [item for sublist in filtered_questions['Tags'].values for item in sublist]

keywords = nltk.FreqDist(flat_list)

keywords = nltk.FreqDist(keywords)

frequencies_words = keywords.most_common(100)
tags_features = [word[0] for word in frequencies_words]

# %%
tags_features
# Out:
# ['python',
#  'django',
#  'numpy',
#  'matplotlib',
#  'pandas',
#  'python-3.x',
#  'python-2.7',
#  'list',
#  'string',
#  'flask',
#  'dictionary',
#  'scipy',
#  'regex',
#  'performance',
#  'google-app-engine',
#  'sqlalchemy',
#  'arrays',
#  'pip',
#  'windows',
#  'algorithm',
#  'unit-testing',
#  'linux',
#  'unicode',
#  'multithreading',
#  'django-models',
#  'osx',
#  'json',
#  'datetime',
#  'c++',
#  'mysql',
#  'virtualenv',
#  'multiprocessing',
#  'subprocess',
#  'class',
#  'java',
#  'c',
#  'ipython',
#  'file',
#  'csv',
#  'logging',
#  'exception',
#  'opencv',
#  'sorting',
#  'selenium',
#  'tkinter',
#  'python-imaging-library',
#  'javascript',
#  'module',
#  'celery',
#  'function',
#  'import',
#  'parsing',
#  'cython',
#  'scikit-learn',
#  'math',
#  'xml',
#  'dataframe',
#  'html',
#  'pycharm',
#  'machine-learning',
#  'beautifulsoup',
#  'plot',
#  'list-comprehension',
#  'generator',
#  'django-admin',
#  'pyqt',
#  'postgresql',
#  'debugging',
#  'nltk',
#  'tuples',
#  'file-io',
#  'urllib2',
#  'oop',
#  'setuptools',
#  'sockets',
#  'decorator',
#  'image-processing',
#  'image',
#  'ruby',
#  'scrapy',
#  'sql',
#  'ubuntu',
#  'database',
#  'argparse',
#  'http',
#  'random',
#  'optimization',
#  'python-2.x',
#  'pickle',
#  'python-import',
#  'python-requests',
#  'inheritance',
#  'nlp',
#  'lxml',
#  'twisted',
#  'jinja2',
#  'php',
#  'django-templates',
#  'mongodb',
#  'sqlite']

# %%
def most_common(tags):
    tags_filtered = []
    for i in range(0, len(tags)):
        if tags[i] in tags_features:
            tags_filtered.append(tags[i])
    return tags_filtered

# %%
filtered_questions['Tags'] = filtered_questions['Tags'].apply(lambda x: most_common(x))
filtered_questions['Tags'] = filtered_questions['Tags'].apply(lambda x: x if len(x)>0 else None)
# Out:
# <ipython-input-21-6ea459496bfd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Tags'] = filtered_questions['Tags'].apply(lambda x: most_common(x))
# <ipython-input-21-6ea459496bfd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Tags'] = filtered_questions['Tags'].apply(lambda x: x if len(x)>0 else None)

# %%
filtered_questions.head()
# Out:
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body                      Tags
# 0  <p>I am using the Photoshop's javascript API t...             [python, osx]
# 1  <p>I have a cross-platform (Python) applicatio...  [python, windows, image]
# 2  <p>I'm starting work on a hobby project with a...                  [python]
# 3  <p>There are several ways to iterate over a re...   [python, sql, database]
# 4  <p>I don't remember whether I was dreaming or ...          [python, arrays]

# %%
filtered_questions.shape
# Out:
# (42420, 3)

# %%
filtered_questions.dropna(subset=['Tags'], inplace=True)
# Out:
# <ipython-input-24-fa6358bad279>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions.dropna(subset=['Tags'], inplace=True)

# %%
filtered_questions.shape
# Out:
# (42420, 3)

# %%
filtered_questions.head()
# Out:
#                                                Title  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
# 2  Continuous Integration System for a Python Cod...
# 3     cx_Oracle: How do I iterate over a result set?
# 4  Using 'in' to match an attribute of Python obj...
#
#                                                 Body                      Tags
# 0  <p>I am using the Photoshop's javascript API t...             [python, osx]
# 1  <p>I have a cross-platform (Python) applicatio...  [python, windows, image]
# 2  <p>I'm starting work on a hobby project with a...                  [python]
# 3  <p>There are several ways to iterate over a re...   [python, sql, database]
# 4  <p>I don't remember whether I was dreaming or ...          [python, arrays]

# %%
filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: BeautifulSoup(x).get_text())
# Out:
# <ipython-input-27-8ecb4599bb37>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: BeautifulSoup(x).get_text())

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"what's", "what is ", text)
    text = re.sub(r"\'s", " ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "can not ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r"\'scuse", " excuse ", text)
    text = re.sub(r"\'\n", " ", text)
    text = re.sub(r"\'\xa0", " ", text)
    text = re.sub('\s+', ' ', text)
    text = text.strip(' ')
    return text

# %%
filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: clean_text(x))
# Out:
# <ipython-input-29-d8bc2ad011d5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: clean_text(x))

# %%
token=ToktokTokenizer()

# %%
punct = '!"#$%&\'()*+,./:;<=>?@[\\]^_`{|}~'

# %%
def strip_list_noempty(mylist):
    newlist = (item.strip() if hasattr(item, 'strip') else item for item in mylist)
    return [item for item in newlist if item != '']

# %%
def clean_punct(text): 
    words=token.tokenize(text)
    punctuation_filtered = []
    regex = re.compile('[%s]' % re.escape(punct))
    remove_punctuation = str.maketrans(' ', ' ', punct)
    for w in words:
        if w in tags_features:
            punctuation_filtered.append(w)
        else:
            punctuation_filtered.append(regex.sub('', w))
  
    filtered_list = strip_list_noempty(punctuation_filtered)
        
    return ' '.join(map(str, filtered_list))

# %%
filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: clean_punct(x))
filtered_questions['Body'][2]
# Out:
# <ipython-input-34-d0885400f7c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: clean_punct(x))
# 'i am starting work on a hobby project with a python codebase and would like to set up some form of continuous integration ie running a battery of test-cases each time a check-in is made and sending nag e-mails to responsible persons when the tests fail similar to cruisecontrol or teamcity i realize i could do this with hooks in most vcses but that requires that the tests run on the same machine as the version control server which is not as elegant as i would like does anyone have any suggestions for a small user-friendly open-source continuous integration system suitable for a python codebase'

# %%
lemma=WordNetLemmatizer()
stop_words = set(stopwords.words("english"))

# %%
def lemitizeWords(text):
    words=token.tokenize(text)
    listLemma=[]
    for w in words:
        x=lemma.lemmatize(w, pos="v")
        listLemma.append(x)
    return ' '.join(map(str, listLemma))

def stopWordsRemove(text):
    
    stop_words = set(stopwords.words("english"))
    
    words=token.tokenize(text)
    
    filtered = [w for w in words if not w in stop_words]
    
    return ' '.join(map(str, filtered))

# %%
filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: lemitizeWords(x)) 
filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: stopWordsRemove(x))
# Out:
# <ipython-input-37-266eab8f05a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: lemitizeWords(x))
# <ipython-input-37-266eab8f05a1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Body'] = filtered_questions['Body'].apply(lambda x: stopWordsRemove(x))

# %%
filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: str(x))
filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: clean_text(x)) 
filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: clean_punct(x)) 
filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: lemitizeWords(x)) 
filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: stopWordsRemove(x))
# Out:
# <ipython-input-38-3ccc56a9c38f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: str(x))
# <ipython-input-38-3ccc56a9c38f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: clean_text(x))
# <ipython-input-38-3ccc56a9c38f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: clean_punct(x))
# <ipython-input-38-3ccc56a9c38f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: lemitizeWords(x))
# <ipython-input-38-3ccc56a9c38f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_questions['Title'] = filtered_questions['Title'].apply(lambda x: stopWordsRemove(x))

# %%
filtered_questions.head(10)
# Out:
#                                            Title  \
# 0           find full path font display name mac
# 1                   get preview jpeg pdf windows
# 2  continuous integration system python codebase
# 3                    cxoracle iterate result set
# 4        use match attribute python object array
# 5                              class view django
# 6                                   python mysql
# 7                    use python itertoolsgroupby
# 8               add method exist object instance
# 9                 express binary literals python
#
#                                                 Body  \
# 0  use photoshop javascript api find fonts give p...
# 1  cross-platform python application need generat...
# 2  start work hobby project python codebase would...
# 3           several ways iterate result set tradeoff
# 4  remember whether dream seem recall function al...
# 5  django view point function problem want change...
# 6  get python work postgresql cannot get work mys...
# 7  able find understandable explanation actually ...
# 8  read possible add method exist object eg class...
# 9  express integer binary number python literals ...
#
#                           Tags
# 0                [python, osx]
# 1     [python, windows, image]
# 2                     [python]
# 3      [python, sql, database]
# 4             [python, arrays]
# 5        [python, django, oop]
# 6  [python, mysql, postgresql]
# 7                     [python]
# 8                [python, oop]
# 9                     [python]

# %%
X1 = filtered_questions['Body']
X2 = filtered_questions['Title']
y = filtered_questions['Tags']

# %%
vectorizer_X1 = TfidfVectorizer(analyzer = 'word',
                                       min_df=0.0,
                                       max_df = 1.0,
                                       strip_accents = None,
                                       encoding = 'utf-8', 
                                       preprocessor=None,
                                       token_pattern=r"(?u)\S\S+",
                                       max_features=1000)

vectorizer_X2 = TfidfVectorizer(analyzer = 'word',
                                       min_df=0.0,
                                       max_df = 1.0,
                                       strip_accents = None,
                                       encoding = 'utf-8', 
                                       preprocessor=None,
                                       token_pattern=r"(?u)\S\S+",
                                       max_features=1000)

# %%
X1_tfidf = vectorizer_X1.fit_transform(X1)
X2_tfidf = vectorizer_X2.fit_transform(X2)

# %%
X_tfidf = hstack([X1_tfidf,X2_tfidf])

# %%
multilabel_binarizer = MultiLabelBinarizer()
y_bin = multilabel_binarizer.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y_bin, test_size = 0.2, random_state = 0)

# %%
def avg_jacard(y_true,y_pred):
    jacard = np.minimum(y_true,y_pred).sum(axis=1) / np.maximum(y_true,y_pred).sum(axis=1)
    
    return jacard.mean()*100

def print_score(y_pred, clf):
    print("Clf: ", clf.__class__.__name__)
    print("Jacard score: {}".format(avg_jacard(y_test, y_pred)))
    print("Hamming loss: {}".format(hamming_loss(y_pred, y_test)*100))
    print("---")

# %%
sgd = SGDClassifier()
clf = OneVsRestClassifier(sgd)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print_score(y_pred, sgd)
# Out:
# d:\python\lib\site-packages\sklearn\multiclass.py:80: UserWarning: Label 68 is present in all training examples.
#   warnings.warn("Label %s is present in all training examples." %
# Clf:  SGDClassifier
# Jacard score: 77.42534967782491
# Hamming loss: 0.593941537010844
# ---

# %%
for i in range(y_train.shape[1]):
    print(multilabel_binarizer.classes_[i])
    print(confusion_matrix(y_test[:,i], y_pred[:,i]))
    print("")
# Out:
# algorithm
# [[8385    5]
#  [  84   10]]
#
# argparse
# [[8455    0]
#  [   3   26]]
#
# arrays
# [[8397    0]
#  [  84    3]]
#
# beautifulsoup
# [[8429    1]
#  [  23   31]]
#
# c
# [[8407    0]
#  [  77    0]]
#
# c++
# [[8401    9]
#  [  47   27]]
#
# celery
# [[8428    1]
#  [   6   49]]
#
# class
# [[8419    0]
#  [  65    0]]
#
# csv
# [[8417    9]
#  [  14   44]]
#
# cython
# [[8437    1]
#  [  12   34]]
#
# database
# [[8446    0]
#  [  38    0]]
#
# dataframe
# [[8429    0]
#  [  55    0]]
#
# datetime
# [[8392   10]
#  [  53   29]]
#
# debugging
# [[8440    3]
#  [  38    3]]
#
# decorator
# [[8428    8]
#  [  13   35]]
#
# dictionary
# [[8284   43]
#  [  54  103]]
#
# django
# [[7700   37]
#  [ 143  604]]
#
# django-admin
# [[8419   13]
#  [  19   33]]
#
# django-models
# [[8404    0]
#  [  80    0]]
#
# django-templates
# [[8451    0]
#  [  33    0]]
#
# exception
# [[8417    7]
#  [  54    6]]
#
# file
# [[8427    0]
#  [  57    0]]
#
# file-io
# [[8445    0]
#  [  39    0]]
#
# flask
# [[8312    3]
#  [  51  118]]
#
# function
# [[8437    0]
#  [  47    0]]
#
# generator
# [[8438   10]
#  [  20   16]]
#
# google-app-engine
# [[8359    9]
#  [  43   73]]
#
# html
# [[8440    3]
#  [  39    2]]
#
# http
# [[8443    0]
#  [  41    0]]
#
# image
# [[8442    0]
#  [  42    0]]
#
# image-processing
# [[8441    0]
#  [  43    0]]
#
# import
# [[8423    0]
#  [  61    0]]
#
# inheritance
# [[8444    0]
#  [  40    0]]
#
# ipython
# [[8423    5]
#  [  14   42]]
#
# java
# [[8414    2]
#  [  42   26]]
#
# javascript
# [[8419    1]
#  [  37   27]]
#
# jinja2
# [[8452    0]
#  [   8   24]]
#
# json
# [[8382   11]
#  [  26   65]]
#
# linux
# [[8353    8]
#  [  95   28]]
#
# list
# [[8174   54]
#  [ 164   92]]
#
# list-comprehension
# [[8435    5]
#  [  23   21]]
#
# logging
# [[8409   13]
#  [  14   48]]
#
# lxml
# [[8458    0]
#  [   7   19]]
#
# machine-learning
# [[8438    0]
#  [  46    0]]
#
# math
# [[8434    0]
#  [  50    0]]
#
# matplotlib
# [[8147   24]
#  [  38  275]]
#
# module
# [[8442    0]
#  [  42    0]]
#
# mongodb
# [[8439    4]
#  [  15   26]]
#
# multiprocessing
# [[8395    5]
#  [  30   54]]
#
# multithreading
# [[8409    8]
#  [  35   32]]
#
# mysql
# [[8398    8]
#  [  35   43]]
#
# nlp
# [[8436    0]
#  [  48    0]]
#
# nltk
# [[8435    0]
#  [  22   27]]
#
# numpy
# [[7972   25]
#  [ 184  303]]
#
# oop
# [[8449    0]
#  [  35    0]]
#
# opencv
# [[8428    0]
#  [  19   37]]
#
# optimization
# [[8453    0]
#  [  31    0]]
#
# osx
# [[8380   17]
#  [  55   32]]
#
# pandas
# [[8194    5]
#  [  45  240]]
#
# parsing
# [[8425    0]
#  [  59    0]]
#
# performance
# [[8367    2]
#  [ 111    4]]
#
# php
# [[8450    5]
#  [  14   15]]
#
# pickle
# [[8445    3]
#  [  12   24]]
#
# pip
# [[8361   14]
#  [  37   72]]
#
# plot
# [[8431    0]
#  [  53    0]]
#
# postgresql
# [[8451    0]
#  [  25    8]]
#
# pycharm
# [[8440    1]
#  [   6   37]]
#
# pyqt
# [[8443    3]
#  [  21   17]]
#
# python
# [[8484]]
#
# python-2.7
# [[8205    0]
#  [ 279    0]]
#
# python-2.x
# [[8456    0]
#  [  28    0]]
#
# python-3.x
# [[8222    7]
#  [ 237   18]]
#
# python-imaging-library
# [[8433    3]
#  [  11   37]]
#
# python-import
# [[8465    0]
#  [  19    0]]
#
# python-requests
# [[8443    0]
#  [  39    2]]
#
# random
# [[8435   11]
#  [  19   19]]
#
# regex
# [[8344    6]
#  [  52   82]]
#
# ruby
# [[8437    2]
#  [  26   19]]
#
# scikit-learn
# [[8434    1]
#  [  16   33]]
#
# scipy
# [[8335    7]
#  [  94   48]]
#
# scrapy
# [[8441    0]
#  [   7   36]]
#
# selenium
# [[8420    3]
#  [  10   51]]
#
# setuptools
# [[8440    3]
#  [  32    9]]
#
# sockets
# [[8442    7]
#  [  23   12]]
#
# sorting
# [[8421   15]
#  [  20   28]]
#
# sql
# [[8446    0]
#  [  38    0]]
#
# sqlalchemy
# [[8382    1]
#  [  23   78]]
#
# sqlite
# [[8445    7]
#  [  21   11]]
#
# string
# [[8317    7]
#  [ 146   14]]
#
# subprocess
# [[8408    8]
#  [  31   37]]
#
# tkinter
# [[8429    1]
#  [  12   42]]
#
# tuples
# [[8435    4]
#  [  35   10]]
#
# twisted
# [[8456    3]
#  [   5   20]]
#
# ubuntu
# [[8437   11]
#  [  23   13]]
#
# unicode
# [[8378   15]
#  [  39   52]]
#
# unit-testing
# [[8383   14]
#  [  37   50]]
#
# urllib2
# [[8445    3]
#  [  17   19]]
#
# virtualenv
# [[8408    7]
#  [  23   46]]
#
# windows
# [[8361   11]
#  [  99   13]]
#
# xml
# [[8435    4]
#  [  15   30]]

# %%
answers = pd.read_csv("Answers.csv")
answers.head()
# Out:
#     Id  OwnerUserId          CreationDate  ParentId  Score  \
# 0  497         50.0  2008-08-02T16:56:53Z       469      4
# 1  518        153.0  2008-08-02T17:42:28Z       469      2
# 2  536        161.0  2008-08-02T18:49:07Z       502      9
# 3  538        156.0  2008-08-02T18:56:56Z       535     23
# 4  541        157.0  2008-08-02T19:06:40Z       535     20
#
#                                                 Body
# 0  <p>open up a terminal (Applications-&gt;Utilit...
# 1  <p>I haven't been able to find anything that d...
# 2  <p>You can use ImageMagick's convert utility f...
# 3  <p>One possibility is Hudson.  It's written in...
# 4  <p>We run <a href="http://buildbot.net/trac">B...

# %%
grouped_tags_final.head(5)
# Out:
#     Id                                               Tags
# 0  469                         python osx fonts photoshop
# 1  502                           python windows image pdf
# 2  535  python continuous-integration extreme-programming
# 3  594               python sql database oracle cx-oracle
# 4  683                            python arrays iteration

# %%
answers.drop(columns=['OwnerUserId', 'CreationDate', 'Id'], inplace=True)

# %%
answers.rename(columns = {'ParentId':'Id'},inplace=True)

# %%
answers = answers.merge(grouped_tags_final, on='Id')
answers.head()
# Out:
#     Id  Score                                               Body  \
# 0  469      4  <p>open up a terminal (Applications-&gt;Utilit...
# 1  469      2  <p>I haven't been able to find anything that d...
# 2  469     12  <p>Unfortunately the only API that isn't depre...
# 3  469      1  <p>There must be a method in Cocoa to get a li...
# 4  502      9  <p>You can use ImageMagick's convert utility f...
#
#                          Tags
# 0  python osx fonts photoshop
# 1  python osx fonts photoshop
# 2  python osx fonts photoshop
# 3  python osx fonts photoshop
# 4    python windows image pdf

# %%
answers = answers[answers['Score']>5]
answers.head()
# Out:
#     Id  Score                                               Body  \
# 2  469     12  <p>Unfortunately the only API that isn't depre...
# 4  502      9  <p>You can use ImageMagick's convert utility f...
# 6  502     25  <p>ImageMagick delegates the PDF->bitmap conve...
# 7  535     23  <p>One possibility is Hudson.  It's written in...
# 8  535     20  <p>We run <a href="http://buildbot.net/trac">B...
#
#                                                 Tags
# 2                         python osx fonts photoshop
# 4                           python windows image pdf
# 6                           python windows image pdf
# 7  python continuous-integration extreme-programming
# 8  python continuous-integration extreme-programming

# %%
answers['Tags'] = answers['Tags'].apply(lambda x: x.split())
answers.head()
# Out:
#     Id  Score                                               Body  \
# 2  469     12  <p>Unfortunately the only API that isn't depre...
# 4  502      9  <p>You can use ImageMagick's convert utility f...
# 6  502     25  <p>ImageMagick delegates the PDF->bitmap conve...
# 7  535     23  <p>One possibility is Hudson.  It's written in...
# 8  535     20  <p>We run <a href="http://buildbot.net/trac">B...
#
#                                                 Tags
# 2                    [python, osx, fonts, photoshop]
# 4                      [python, windows, image, pdf]
# 6                      [python, windows, image, pdf]
# 7  [python, continuous-integration, extreme-progr...
# 8  [python, continuous-integration, extreme-progr...

# %%
answers.shape
# Out:
# (93192, 4)

# %%
answers.drop(columns=['Id', 'Score'], inplace=True)
answers.head()
# Out:
#                                                 Body  \
# 2  <p>Unfortunately the only API that isn't depre...
# 4  <p>You can use ImageMagick's convert utility f...
# 6  <p>ImageMagick delegates the PDF->bitmap conve...
# 7  <p>One possibility is Hudson.  It's written in...
# 8  <p>We run <a href="http://buildbot.net/trac">B...
#
#                                                 Tags
# 2                    [python, osx, fonts, photoshop]
# 4                      [python, windows, image, pdf]
# 6                      [python, windows, image, pdf]
# 7  [python, continuous-integration, extreme-progr...
# 8  [python, continuous-integration, extreme-progr...

# %%
answers['Body'] = answers['Body'].apply(lambda x: BeautifulSoup(x).get_text())

# %%
answers['Body'] = answers['Body'].apply(lambda x: clean_text(x))

# %%
answers['Body'] = answers['Body'].apply(lambda x: clean_punct(x))
answers['Body'][2]
# Out:
# 'unfortunately the only api that is not deprecated is located in the applicationservices framework which does not have a bridge support file and thus is not available in the bridge if you are wanting to use ctypes you can use atsfontgetfilereference after looking up the atsfontref cocoa does not have any native support at least as of 105 for getting the location of a font'

# %%
answers['Body'] = answers['Body'].apply(lambda x: lemitizeWords(x)) 
answers['Body'] = answers['Body'].apply(lambda x: stopWordsRemove(x)) 

answers.head()
# Out:
#                                                 Body  \
# 2  unfortunately api deprecate locate application...
# 4  use imagemagick convert utility see examples h...
# 6  imagemagick delegate pdf-bitmap conversion gho...
# 7  one possibility hudson write java integration ...
# 8  run buildbot - trac work use much since code b...
#
#                                                 Tags
# 2                    [python, osx, fonts, photoshop]
# 4                      [python, windows, image, pdf]
# 6                      [python, windows, image, pdf]
# 7  [python, continuous-integration, extreme-progr...
# 8  [python, continuous-integration, extreme-progr...

# %%
def print_top10(feature_names, clf, class_labels):
    """Prints features with the highest coefficient values, per class"""
    for i, class_label in enumerate(class_labels):
        top10 = np.argsort(clf.coef_[i])[-10:]
        print("--------------------------------------------")
        print("%s: %s" % (class_label,
              " ".join(feature_names[j] for j in top10)))
        print("--------------------------------------------")

# %%
feature_names = vectorizer_X1.get_feature_names() + vectorizer_X2.get_feature_names()

# %%
samq = '''In a multilabel classification problem, i use MultiLabelBinarizer to transform my 20 text labels into a binary list of zeros and ones.

After prediction I get my list of 20 binary values, and I would like to output the corresponding text labels.

I am just wondering whether MultiLabelBinarizer() provides a getting back transformation or I should do it manually.


'''

# %%
print(samq)
# Out:
# In a multilabel classification problem, i use MultiLabelBinarizer to transform my 20 text labels into a binary list of zeros and ones.
#
# After prediction I get my list of 20 binary values, and I would like to output the corresponding text labels.
#
# I am just wondering whether MultiLabelBinarizer() provides a getting back transformation or I should do it manually.

# %%
samq = BeautifulSoup(samq).get_text()

# %%
samq = clean_text(samq)
samq = clean_punct(samq)

# %%
samq = lemitizeWords(samq)
samq = stopWordsRemove(samq)

# %%
samq
# Out:
# 'multilabel classification problem use multilabelbinarizer transform 20 text label binary list zero ones prediction get list 20 binary value would like output correspond text label wonder whether multilabelbinarizer provide get back transformation manually'

# %%
samq = vectorizer_X1.transform([samq])

# %%
samq
# Out:
# <1x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 19 stored elements in Compressed Sparse Row format>

# %%
multilabel_binarizer.inverse_transform(clf.predict(X_test))
# Out:
# [('python',),
#  ('python',),
#  ('linux', 'python'),
#  ('numpy', 'python'),
#  ('django', 'python'),
#  ('list', 'python', 'tuples'),
#  ('decorator', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('pycharm', 'python'),
#  ('python',),
#  ('nltk', 'python'),
#  ('python', 'tkinter'),
#  ('python', 'scrapy'),
#  ('python',),
#  ('mongodb', 'pandas', 'python'),
#  ('python',),
#  ('python', 'scikit-learn'),
#  ('python', 'sqlalchemy'),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('numpy', 'python'),
#  ('python',),
#  ('python', 'windows'),
#  ('python',),
#  ('jinja2', 'python'),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('matplotlib', 'python'),
#  ('algorithm', 'python'),
#  ('python', 'regex'),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('pip', 'python'),
#  ('python',),
#  ('python',),
#  ('pip', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('logging', 'python'),
#  ('google-app-engine', 'python'),
#  ('python',),
#  ('multiprocessing', 'python'),
#  ('python',),
#  ('list', 'python'),
#  ('python',),
#  ('numpy', 'python'),
#  ('python', 'string'),
#  ('python',),
#  ('python',),
#  ('python', 'virtualenv'),
#  ('python',),
#  ('list', 'python'),
#  ('django', 'django-admin', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'regex'),
#  ('python',),
#  ('logging', 'python'),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'twisted'),
#  ('python',),
#  ('pickle', 'python'),
#  ('pandas', 'python'),
#  ('google-app-engine', 'python'),
#  ('django', 'python'),
#  ('dictionary', 'python'),
#  ('python',),
#  ('python', 'scikit-learn'),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('multiprocessing', 'python'),
#  ('django', 'python'),
#  ('django', 'python'),
#  ('opencv', 'python'),
#  ('python',),
#  ('python',),
#  ('json', 'python'),
#  ('list', 'python'),
#  ('python',),
#  ('java', 'python'),
#  ('python', 'tuples'),
#  ('python',),
#  ('pandas', 'python'),
#  ('csv', 'python'),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('csv', 'python'),
#  ('python',),
#  ('multithreading', 'python'),
#  ('python',),
#  ('opencv', 'python', 'python-imaging-library'),
#  ('mysql', 'python'),
#  ('python',),
#  ('numpy', 'python'),
#  ('beautifulsoup', 'python'),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python', 'windows'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('mysql', 'python'),
#  ('python',),
#  ('dictionary', 'json', 'python'),
#  ('flask', 'jinja2', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('osx', 'python'),
#  ('python',),
#  ('pandas', 'python'),
#  ('list-comprehension', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'virtualenv'),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'scrapy'),
#  ('python',),
#  ('python',),
#  ('dictionary', 'json', 'python'),
#  ('numpy', 'python'),
#  ('multithreading', 'python'),
#  ('python',),
#  ('celery', 'python'),
#  ('php', 'python'),
#  ('pickle', 'python'),
#  ('multiprocessing', 'python'),
#  ('python', 'unit-testing'),
#  ('python', 'python-3.x'),
#  ('python',),
#  ('django', 'python'),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('logging', 'python'),
#  ('flask', 'python'),
#  ('mysql', 'python'),
#  ('python', 'sorting'),
#  ('python',),
#  ('python',),
#  ('python', 'string'),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('nltk', 'python'),
#  ('python',),
#  ('python',),
#  ('pandas', 'python'),
#  ('python',),
#  ('django', 'django-admin', 'python'),
#  ('python',),
#  ('python',),
#  ('c++', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('csv', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('pandas', 'python'),
#  ('numpy', 'python'),
#  ('python', 'sqlalchemy'),
#  ('pycharm', 'python'),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('pandas', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('numpy', 'python'),
#  ('python',),
#  ('multithreading', 'python'),
#  ('python',),
#  ('python',),
#  ('django', 'django-admin', 'python'),
#  ('python',),
#  ('generator', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'sqlalchemy'),
#  ('django', 'python'),
#  ('django', 'python'),
#  ('numpy', 'python'),
#  ('matplotlib', 'python'),
#  ('django', 'python'),
#  ('python',),
#  ('javascript', 'python'),
#  ('python', 'tkinter'),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python',),
#  ('dictionary', 'python'),
#  ('python',),
#  ('dictionary', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('generator', 'python'),
#  ('python',),
#  ('pandas', 'python'),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python',),
#  ('java', 'php', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('celery', 'django', 'python'),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python', 'regex'),
#  ('python',),
#  ('beautifulsoup', 'python', 'selenium'),
#  ('django', 'python'),
#  ('django', 'python'),
#  ('matplotlib', 'osx', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python', 'scipy'),
#  ('python',),
#  ('pyqt', 'python'),
#  ('cython', 'python'),
#  ('numpy', 'python'),
#  ('flask', 'python'),
#  ('python',),
#  ('python',),
#  ('celery', 'python'),
#  ('flask', 'python'),
#  ('datetime', 'python'),
#  ('ipython', 'python'),
#  ('python', 'python-imaging-library'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python', 'string', 'unicode'),
#  ('dictionary', 'django', 'python'),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python', 'regex'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('numpy', 'pandas', 'python'),
#  ('python', 'scikit-learn'),
#  ('python',),
#  ('python',),
#  ('ipython', 'python'),
#  ('python',),
#  ('numpy', 'python'),
#  ('django', 'python'),
#  ('datetime', 'python'),
#  ('python',),
#  ('python', 'regex'),
#  ('python',),
#  ('mysql', 'python'),
#  ('python',),
#  ('dictionary', 'python'),
#  ('pip', 'python', 'virtualenv'),
#  ('python', 'python-imaging-library'),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('mysql', 'osx', 'python'),
#  ('python',),
#  ('python',),
#  ('osx', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'scipy'),
#  ('python',),
#  ('python',),
#  ('nltk', 'python'),
#  ('python',),
#  ('pip', 'python'),
#  ('csv', 'python'),
#  ('python',),
#  ('pandas', 'python'),
#  ('python', 'sqlalchemy'),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'regex'),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('pandas', 'python'),
#  ('django', 'python'),
#  ('python', 'tkinter'),
#  ('django', 'python'),
#  ('linux', 'python'),
#  ('python',),
#  ('multiprocessing', 'python'),
#  ('python',),
#  ('list', 'python'),
#  ('django', 'python'),
#  ('flask', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'scrapy'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('dictionary', 'python'),
#  ('python',),
#  ('python',),
#  ('pandas', 'python'),
#  ('django', 'python'),
#  ('pandas', 'python'),
#  ('python', 'virtualenv'),
#  ('linux', 'python'),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('linux', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('google-app-engine', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'unicode'),
#  ('csv', 'python'),
#  ('beautifulsoup', 'python'),
#  ('numpy', 'python'),
#  ('arrays', 'numpy', 'python'),
#  ('python',),
#  ('python', 'ruby'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('celery', 'python'),
#  ('python',),
#  ('mysql', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('list', 'python'),
#  ('django', 'python'),
#  ('osx', 'python'),
#  ('python',),
#  ('python',),
#  ('dictionary', 'list', 'python'),
#  ('python',),
#  ('python',),
#  ('opencv', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('python', 'random'),
#  ('logging', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'unit-testing'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('argparse', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'setuptools'),
#  ('celery', 'python'),
#  ('numpy', 'python'),
#  ('python', 'unit-testing'),
#  ('python', 'regex'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python', 'python-imaging-library'),
#  ('django', 'python'),
#  ('python', 'python-imaging-library'),
#  ('python',),
#  ('python',),
#  ('jinja2', 'python'),
#  ('python', 'python-3.x'),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('mysql', 'python', 'sqlite'),
#  ('python', 'scipy'),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'selenium'),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('pip', 'python'),
#  ('pip', 'python'),
#  ('json', 'python'),
#  ('flask', 'python'),
#  ('python',),
#  ('python', 'scrapy'),
#  ('java', 'python'),
#  ('logging', 'python'),
#  ('python',),
#  ('python', 'virtualenv'),
#  ('python', 'random'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('flask', 'python'),
#  ('python',),
#  ('flask', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('numpy', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python', 'regex'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'django-admin', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('google-app-engine', 'python'),
#  ('django', 'python'),
#  ('python',),
#  ('csv', 'python'),
#  ('datetime', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('nltk', 'python'),
#  ('python',),
#  ('pandas', 'python'),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('celery', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'unit-testing'),
#  ('python',),
#  ('python', 'unit-testing'),
#  ('python',),
#  ('django', 'django-admin', 'python'),
#  ('python', 'sqlalchemy'),
#  ('datetime', 'python'),
#  ('python', 'subprocess'),
#  ('matplotlib', 'python'),
#  ('django', 'python'),
#  ('matplotlib', 'python'),
#  ('python', 'unicode'),
#  ('python',),
#  ('numpy', 'python'),
#  ('numpy', 'python'),
#  ('numpy', 'osx', 'python', 'scipy'),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('pip', 'python'),
#  ('csv', 'python', 'unicode'),
#  ('multithreading', 'python'),
#  ('json', 'python'),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python', 'sockets'),
#  ('python',),
#  ('dictionary', 'python', 'sorting'),
#  ('mysql', 'python'),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python', 'unit-testing'),
#  ('django', 'python'),
#  ('python', 'twisted'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('list', 'python'),
#  ('list', 'python'),
#  ('python',),
#  ('python', 'unit-testing'),
#  ('python',),
#  ('python', 'tkinter'),
#  ('python',),
#  ('numpy', 'python', 'scipy'),
#  ('python',),
#  ('python',),
#  ('python', 'regex', 'ruby'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('google-app-engine', 'python'),
#  ('csv', 'python'),
#  ('pandas', 'python'),
#  ('python',),
#  ('django', 'django-admin', 'python'),
#  ('postgresql', 'python'),
#  ('python', 'virtualenv'),
#  ('python', 'sqlite'),
#  ('python',),
#  ('logging', 'python'),
#  ('python', 'unicode'),
#  ('python', 'windows'),
#  ('pandas', 'python'),
#  ('python',),
#  ('python', 'unit-testing'),
#  ('python',),
#  ('nltk', 'python'),
#  ('numpy', 'python'),
#  ('mysql', 'python'),
#  ('django', 'mysql', 'python'),
#  ('python',),
#  ('python',),
#  ('linux', 'python'),
#  ('python',),
#  ('json', 'python'),
#  ('python', 'ruby'),
#  ('django', 'google-app-engine', 'python'),
#  ('python',),
#  ('python',),
#  ('argparse', 'python'),
#  ('django', 'google-app-engine', 'json', 'python'),
#  ('pip', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'unit-testing'),
#  ('pycharm', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'python-imaging-library'),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('java', 'python'),
#  ('python', 'virtualenv'),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('python', 'sqlalchemy'),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('pandas', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('nltk', 'python'),
#  ('python',),
#  ('logging', 'python', 'unit-testing'),
#  ('pickle', 'python'),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('pip', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'regex'),
#  ('python',),
#  ('python',),
#  ('python', 'unit-testing'),
#  ('pandas', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('ipython', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'unicode'),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python', 'virtualenv'),
#  ('python',),
#  ('python',),
#  ('jinja2', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('list', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'string'),
#  ('python',),
#  ('python', 'selenium'),
#  ('nltk', 'python'),
#  ('python',),
#  ('django', 'python', 'sqlalchemy'),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('dictionary', 'python'),
#  ('python',),
#  ('python', 'setuptools', 'virtualenv'),
#  ('python', 'unicode'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('json', 'python'),
#  ('pandas', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'sorting'),
#  ('pandas', 'python'),
#  ('python', 'twisted'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('list', 'python'),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('celery', 'python'),
#  ('django', 'python'),
#  ('list', 'python'),
#  ('python',),
#  ('google-app-engine', 'python', 'unit-testing'),
#  ('python',),
#  ('python',),
#  ('c++', 'python'),
#  ('python', 'sorting'),
#  ('python',),
#  ('python', 'unicode'),
#  ('java', 'python'),
#  ('python',),
#  ('numpy', 'python'),
#  ('mysql', 'python', 'unicode'),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('matplotlib', 'pandas', 'python'),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('lxml', 'python', 'xml'),
#  ('python',),
#  ('python',),
#  ('django', 'django-admin', 'python'),
#  ('pip', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'selenium'),
#  ('python',),
#  ('django', 'javascript', 'python'),
#  ('python',),
#  ('pandas', 'python'),
#  ('python', 'sorting'),
#  ('django', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('datetime', 'python', 'sqlite'),
#  ('python',),
#  ('python',),
#  ('flask', 'python'),
#  ('python', 'windows'),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('dictionary', 'python'),
#  ('python',),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('numpy', 'python'),
#  ('list', 'python', 'tuples'),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('dictionary', 'python'),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('multiprocessing', 'python'),
#  ('php', 'python'),
#  ('json', 'python'),
#  ('ipython', 'pycharm', 'python'),
#  ('python',),
#  ('python', 'xml'),
#  ('python',),
#  ('python',),
#  ('python', 'windows'),
#  ('lxml', 'python'),
#  ('python',),
#  ('python',),
#  ('python', 'scikit-learn'),
#  ('python',),
#  ('postgresql', 'python', 'sqlalchemy'),
#  ('numpy', 'python'),
#  ('numpy', 'python'),
#  ('celery', 'python'),
#  ('python',),
#  ('dictionary', 'python'),
#  ('pyqt', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('numpy', 'python', 'scipy'),
#  ('python',),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('ipython', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('flask', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('c++', 'python'),
#  ('python', 'regex'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'selenium'),
#  ('pip', 'python'),
#  ('google-app-engine', 'python'),
#  ('python',),
#  ('matplotlib', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('pandas', 'python'),
#  ('flask', 'python'),
#  ('django', 'python'),
#  ('python',),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('decorator', 'python'),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('dictionary', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('cython', 'python'),
#  ('pyqt', 'python'),
#  ('list', 'python', 'tuples'),
#  ('logging', 'python'),
#  ('python',),
#  ('pyqt', 'python'),
#  ('mysql', 'python'),
#  ('python', 'virtualenv'),
#  ('python',),
#  ('python', 'xml'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'scipy'),
#  ('python',),
#  ('multiprocessing', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'random'),
#  ('list-comprehension', 'python'),
#  ('python',),
#  ('python', 'sqlalchemy'),
#  ('python', 'subprocess'),
#  ('python',),
#  ('python', 'unit-testing'),
#  ('python',),
#  ('django', 'mysql', 'python'),
#  ('python',),
#  ('pandas', 'python'),
#  ('matplotlib', 'pyqt', 'python'),
#  ('python',),
#  ('pandas', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'tkinter'),
#  ('python',),
#  ('multiprocessing', 'python'),
#  ('python',),
#  ('osx', 'python'),
#  ('python',),
#  ('python',),
#  ('list', 'python'),
#  ('numpy', 'opencv', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('django', 'python'),
#  ('python',),
#  ('json', 'python'),
#  ('django', 'django-admin', 'python'),
#  ('numpy', 'python'),
#  ('numpy', 'python'),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python',),
#  ('python', 'virtualenv'),
#  ('python',),
#  ('django', 'python'),
#  ('list-comprehension', 'python'),
#  ('python',),
#  ('django', 'python'),
#  ('python', 'python-imaging-library'),
#  ('ipython', 'python'),
#  ('python',),
#  ...]

# %%
samt = 'Scikit Learn Multilabel Classification, Getting back labels from MultiLabelBinarizer'
samt = clean_text(samt)
samt = clean_punct(samt)
samt = lemitizeWords(samt)
samt = stopWordsRemove(samt)
print(samt)
# Out:
# scikit learn multilabel classification get back label multilabelbinarizer

# %%
samt = vectorizer_X2.transform([samt])

# %%
samt
# Out:
# <1x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %%
q = hstack([samq, samt])

# %%
multilabel_binarizer.inverse_transform(clf.predict(q))
# Out:
# [('python', 'scikit-learn')]
